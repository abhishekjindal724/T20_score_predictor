# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekjindal724/T20_score_predictor/blob/main/T20worldcupscorepredictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

def count_files_in_directory(directory_path):
    try:
        # List all entries in the directory
        directory_contents = os.listdir(directory_path)

        # Count only the files (excluding directories)
        file_count = sum(1 for entry in directory_contents if os.path.isfile(os.path.join(directory_path, entry)))

        return file_count
    except Exception as e:
        print(f"An error occurred: {e}")
        return 0

# Specify your directory path here
desired_path = "/content/drive/MyDrive/t20s/t20s"

# Count files in the specified directory
number_of_files = count_files_in_directory(desired_path)
print(f"Number of files in the directory: {number_of_files}")
# Out:
# Number of files in the directory: 1435

# %%
import os
import pandas as pd
from tqdm import tqdm
from yaml import safe_load
import numpy as np

desired_path = "/content/drive/MyDrive/t20s/t20s"
os.chdir(desired_path)

directory_contents = os.listdir(desired_path)

yaml_files = [file for file in directory_contents if file.endswith('.yaml') or file.endswith('.yml')]
print(f"Number of YAML files to process: {len(yaml_files)}")
for file in yaml_files:
    full_path = os.path.join(desired_path, file)

all_dataframes = []
counter = 1

for file in tqdm(yaml_files):
   full_path = os.path.join(desired_path, file)
   if os.path.exists(full_path):
        with open(full_path, 'r') as f:
            df = pd.json_normalize(safe_load(f))
            df['match_id'] = counter
            all_dataframes.append(df)
            counter += 1
   else:
        print(f"File not found: {full_path}")

final_df = pd.concat(all_dataframes)

print(final_df)
# Out:
# Number of YAML files to process: 1432
# 100%|██████████| 1432/1432 [07:48<00:00,  3.06it/s]
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'United States of Am...                0.9
# 0   [{'1st innings': {'team': 'Fiji', 'deliveries'...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Italy', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'Vanuatu', 'deliveri...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Norway', 'deliverie...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Norway', 'deliverie...                0.9
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
backup_df = final_df.copy()

# %%
from IPython.display import display
display(final_df)
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'United States of Am...                0.9
# 0   [{'1st innings': {'team': 'Fiji', 'deliveries'...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Italy', 'deliveries...                0.9
# 0   [{'1st innings': {'team': 'Vanuatu', 'deliveri...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Norway', 'deliverie...                0.9
# 0   [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Norway', 'deliverie...                0.9
#
#    meta.created  meta.revision      info.city    info.dates info.gender  \
# ...

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'United States of Am...     Lauderhill
# 0   [{'1st innings': {'team': 'Fiji', 'deliveries'...      Port Vila
# 0   [{'1st innings': {'team': 'Australia', 'delive...      Melbourne
# 0   [{'1st innings': {'team': 'Italy', 'deliveries...  St Peter Port
# 0   [{'1st innings': {'team': 'Vanuatu', 'deliveri...      Port Vila
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...   Kuala Lumpur
# 0   [{'1st innings': {'team': 'Australia', 'delive...   Johannesburg
# 0   [{'1st innings': {'team': 'Norway', 'deliverie...  St Peter Port
# 0   [{'1st innings': {'team': 'West Indies', 'deli...         Dublin
# 0   [{'1st innings': {'team': 'Norway', 'deliverie...         Castel
#
#       info.dates info.gender info.match_type       info.outcome.winner  \
# ...

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male      966
# female    466
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
# Out:
# <ipython-input-8-b37d11ffd314>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.gender'],inplace=True)

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    966
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    963
# 50      3
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# <ipython-input-11-2ded84e4f63f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                               innings      info.city  \
# 0   [{'1st innings': {'team': 'Italy', 'deliveries...  St Peter Port
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...         Rajkot
# 0   [{'1st innings': {'team': 'Thailand', 'deliver...   Kuala Lumpur
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...     Wellington
# 0   [{'1st innings': {'team': 'Jersey', 'deliverie...  St Peter Port
# ..                                                ...            ...
# 0   [{'1st innings': {'team': 'New Zealand', 'deli...       Auckland
# 0   [{'1st innings': {'team': 'Malaysia', 'deliver...   Kuala Lumpur
# ...

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
from google.colab import files
files.download('dataset_level1.pkl')

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'bowler': 'TCW Veillard',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'non_striker': 'Manpreet Singh',
#    'batsman': 'BBJL Perera'}},
#  {0.2: {'bowler': 'TCW Veillard',
#    'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#    'non_striker': 'Manpreet Singh',
#    'batsman': 'BBJL Perera'}},
#  {0.3: {'bowler': 'TCW Veillard',
#    'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#    'non_striker': 'Manpreet Singh',
#    'batsman': 'BBJL Perera'}},
#  {0.4: {'non_striker': 'BBJL Perera',
#    'bowler': 'TCW Veillard',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Manpreet Singh'}},
#  {0.5: {'non_striker': 'BBJL Perera',
#    'bowler': 'TCW Veillard',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Manpreet Singh'}},
#  {0.6: {'non_striker': 'BBJL Perera',
#    'bowler': 'TCW Veillard',
#    'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#    'batsman': 'Manpreet Singh'}},
# ...

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():

    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
               player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)

# %%
delivery_df
# Out:
#         match_id               teams batting_team  ball         batsman  \
# 0              2   [Guernsey, Italy]        Italy   0.1     BBJL Perera
# 1              2   [Guernsey, Italy]        Italy   0.2     BBJL Perera
# 2              2   [Guernsey, Italy]        Italy   0.3     BBJL Perera
# 3              2   [Guernsey, Italy]        Italy   0.4  Manpreet Singh
# 4              2   [Guernsey, Italy]        Italy   0.5  Manpreet Singh
# ...          ...                 ...          ...   ...             ...
# 116542       964  [Guernsey, Norway]       Norway  15.2     Tafseer Ali
# 116543       964  [Guernsey, Norway]       Norway  15.3     Tafseer Ali
# 116544       964  [Guernsey, Norway]       Norway  15.4     Nazakat Ali
# 116545       964  [Guernsey, Norway]       Norway  15.5    Khizer Ahmed
# 116546       964  [Guernsey, Norway]       Norway  15.6    Khizer Ahmed
#
#               bowler  runs player_dismissed           city  \
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Italy', 'Bangladesh', 'Thailand', 'New Zealand', 'Jersey',
#        'England', 'India', 'Nigeria', 'Australia', 'Ghana', 'Denmark',
#        'South Africa', 'Pakistan', 'Guernsey', 'Maldives', 'Sri Lanka',
#        'Netherlands', 'Nepal', 'Malaysia', 'West Indies', 'Singapore',
#        'Kuwait', 'Afghanistan', 'Namibia', 'Cayman Islands',
#        'United Arab Emirates', 'Canada', 'Hong Kong', 'Bermuda',
#        'Zimbabwe', 'United States of America', 'Oman', 'Botswana',
#        'Ireland', 'Papua New Guinea', 'Kenya', 'Scotland', 'Vanuatu',
#        'Portugal', 'Gibraltar', 'Bhutan', 'Germany', 'Spain', 'Qatar',
#        'Belgium', 'Isle of Man', 'Bulgaria', 'Iran', 'Romania',
#        'Philippines', 'Uganda', 'Norway'], dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id batting_team  ball        batsman     bowler  runs  \
# 119            3   Bangladesh   0.1      Liton Das  DL Chahar     0
# 120            3   Bangladesh   0.2      Liton Das  DL Chahar     1
# 121            3   Bangladesh   0.3  Mohammad Naim  DL Chahar     0
# 122            3   Bangladesh   0.4  Mohammad Naim  DL Chahar     1
# 123            3   Bangladesh   0.5      Liton Das  DL Chahar     0
# ...          ...          ...   ...            ...        ...   ...
# 116322       962    Australia  19.2        AC Agar   K Rabada     6
# 116323       962    Australia  19.3        AC Agar   K Rabada     2
# 116324       962    Australia  19.4        AC Agar   K Rabada     1
# 116325       962    Australia  19.5       MA Starc   K Rabada     1
# 116326       962    Australia  19.6        AC Agar   K Rabada     4
#
#        player_dismissed          city                                   venue  \
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#         match_id batting_team  bowling_team  ball  runs player_dismissed  \
# 119            3   Bangladesh         India   0.1     0                0
# 120            3   Bangladesh         India   0.2     1                0
# 121            3   Bangladesh         India   0.3     0                0
# 122            3   Bangladesh         India   0.4     1                0
# 123            3   Bangladesh         India   0.5     0                0
# ...          ...          ...           ...   ...   ...              ...
# 116322       962    Australia  South Africa  19.2     6                0
# 116323       962    Australia  South Africa  19.3     2                0
# 116324       962    Australia  South Africa  19.4     1                0
# 116325       962    Australia  South Africa  19.5     1                0
# 116326       962    Australia  South Africa  19.6     4                0
#
#                 city                                   venue
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b36b68ee7b01> in <cell line: 1>()
# ----> 1 pickle.dump(output,open('dataset_level2.pkl','wb'))
#
# NameError: name 'pickle' is not defined

# %%
from google.colab import files
files.download('dataset_level2.pkl')

# %%
df = pickle.load(open('dataset_level2.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad8f6ef4e685> in <cell line: 1>()
# ----> 1 df = pickle.load(open('dataset_level2.pkl','rb'))
#
# NameError: name 'pickle' is not defined
